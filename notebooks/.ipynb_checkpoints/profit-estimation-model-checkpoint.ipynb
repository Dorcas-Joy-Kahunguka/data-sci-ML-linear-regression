# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing the dataset and extracting the independent and dependent variables respectively
companies = pd.read_csv('C:/Users/user/Desktop/Data Science Projects/ML_Projects/Profit_Estimation_LR1/data/1000_Companies.csv')
x=companies.iloc[:, :4].values
y=companies.iloc[:, 4].values
companies.head()
x
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        ...,
#        [100275.47, 241926.31, 227142.82, 'California'],
#        [128456.23, 321652.14, 281692.32, 'California'],
#        [161181.72, 270939.86, 295442.17, 'New York']], dtype=object)

# %%
companies.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#Establishing pairwise correlation of numeric columns

sns.heatmap(companies.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
#Establishing correlation between each of the independent variable and profit.
sns.heatmap(companies.corr(numeric_only=True)[["Profit"]], annot=True)
# Out:
# <Axes: >

# %%
#Encoding categorical data, state column in this case, to numerical format.
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer 

labelencoder=LabelEncoder()
x[:, 3]=labelencoder.fit_transform(x[:, 3])

ct = ColumnTransformer([("encoder", OneHotEncoder(),[3])], remainder="passthrough")
x=ct.fit_transform(x)
x
# Out:
# array([[0.0, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        ...,
#        [1.0, 0.0, 0.0, 100275.47, 241926.31, 227142.82],
#        [1.0, 0.0, 0.0, 128456.23, 321652.14, 281692.32],
#        [0.0, 0.0, 1.0, 161181.72, 270939.86, 295442.17]], dtype=object)

# %%
#Avoiding the dummy variable trap
x=x[:, 1:]
x
# Out:
# array([[0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        ...,
#        [0.0, 0.0, 100275.47, 241926.31, 227142.82],
#        [0.0, 0.0, 128456.23, 321652.14, 281692.32],
#        [0.0, 1.0, 161181.72, 270939.86, 295442.17]], dtype=object)

# %%
#Splitting the data into training and testing sets.
from sklearn.model_selection import train_test_split
#20% of the data will be used for testing
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=0)
